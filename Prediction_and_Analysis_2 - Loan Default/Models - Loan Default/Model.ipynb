# %%
import re
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

import warnings
warnings.filterwarnings("ignore")

# %%
# File Paths
data_path = "../Accepted_Data/2018_Accepted_data/2018_Accepted_data.csv"

# %%
# reading in csv and converting to dataframes
data = pd.read_csv(data_path, error_bad_lines=False,low_memory=False)

# %%
data.head()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  130954621        NaN     5000.0       5000.0           5000.0   36 months
# 1  130964697        NaN    15000.0      15000.0          15000.0   36 months
# 2  130955326        NaN    11200.0      11200.0          11200.0   60 months
# 3  130504052        NaN    25000.0      25000.0          25000.0   60 months
# 4  130956066        NaN     3000.0       3000.0           3000.0   36 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     20.39       186.82     D        D4  ...                            NaN
# 1      9.92       483.45     B        B2  ...                            NaN
# 2     30.79       367.82     G        G1  ...                            NaN
# 3     21.85       688.35     D        D5  ...                            NaN
# 4      7.34        93.10     A        A4  ...                            NaN
#
#   hardship_last_payment_amount disbursement_method  debt_settlement_flag  \
# 0                          NaN                Cash                     N
# 1                          NaN                Cash                     N
# 2                          NaN                Cash                     N
# 3                          NaN                Cash                     N
# 4                          NaN                Cash                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount settlement_percentage  settlement_term
# 0               NaN                   NaN              NaN
# 1               NaN                   NaN              NaN
# 2               NaN                   NaN              NaN
# 3               NaN                   NaN              NaN
# 4               NaN                   NaN              NaN
#
# [5 rows x 151 columns]

# %%
data.shape
# Out:
# (495242, 151)

# %% [markdown]
# #### the dataset I used is derived from the Lending Club for all of 2018. It contains more than 495,000 original loan data of users with 151 attributes.

# %%
# selecting only individual applicants - We'll focus only on individual loans
ind_data = data[data['application_type']=='Individual']

# %%
ind_data.shape
# Out:
# (426257, 151)

# %%
# variables to use
useful_data = ind_data[[
    'loan_amnt',
    'installment',
    'annual_inc',
    'grade',
    'open_acc',
    'total_pymnt',
    'total_rec_int',
    'home_ownership',
    'verification_status',
    'application_type',
    'purpose',
    'term',
    'loan_status'
]]

# %%
useful_data.head()
# Out:
#    loan_amnt  installment  annual_inc grade  open_acc  total_pymnt  \
# 0     5000.0       186.82     50000.0     D       5.0  2043.690000
# 1    15000.0       483.45    196000.0     B      19.0  5301.420000
# 3    25000.0       688.35     65000.0     D       7.0  7511.160000
# 4     3000.0        93.10     52000.0     A       7.0  3011.577285
# 5    17000.0       454.10     52000.0     D       9.0  4956.590000
#
#    total_rec_int home_ownership verification_status application_type  \
# 0         824.00           RENT            Verified       Individual
# 1        1179.92            OWN     Source Verified       Individual
# 3        4699.89       MORTGAGE     Source Verified       Individual
# 4          11.58           RENT     Source Verified       Individual
# 5        2976.36           RENT     Source Verified       Individual
#
#               purpose        term loan_status
# 0               other   36 months     Current
# 1  debt_consolidation   36 months     Current
# 3  debt_consolidation   60 months     Current
# 4      major_purchase   36 months  Fully Paid
# 5  debt_consolidation   60 months     Current

# %%
# checking data for null values
useful_data.isna().any()
# Out:
# loan_amnt              False
# installment            False
# annual_inc             False
# grade                  False
# open_acc               False
# total_pymnt            False
# total_rec_int          False
# home_ownership         False
# verification_status    False
# application_type       False
# purpose                False
# term                   False
# loan_status            False
# dtype: bool

# %% [markdown]
# #### Create new variables/features to consider

# %%
# monthly income
useful_data['monthly_inc'] = useful_data['annual_inc']/12

# %%
useful_data.head()
# Out:
#    loan_amnt  installment  annual_inc grade  open_acc  total_pymnt  \
# 0     5000.0       186.82     50000.0     D       5.0  2043.690000
# 1    15000.0       483.45    196000.0     B      19.0  5301.420000
# 3    25000.0       688.35     65000.0     D       7.0  7511.160000
# 4     3000.0        93.10     52000.0     A       7.0  3011.577285
# 5    17000.0       454.10     52000.0     D       9.0  4956.590000
#
#    total_rec_int home_ownership verification_status application_type  \
# 0         824.00           RENT            Verified       Individual
# 1        1179.92            OWN     Source Verified       Individual
# 3        4699.89       MORTGAGE     Source Verified       Individual
# 4          11.58           RENT     Source Verified       Individual
# 5        2976.36           RENT     Source Verified       Individual
#
#               purpose        term loan_status   monthly_inc
# 0               other   36 months     Current   4166.666667
# 1  debt_consolidation   36 months     Current  16333.333333
# 3  debt_consolidation   60 months     Current   5416.666667
# 4      major_purchase   36 months  Fully Paid   4333.333333
# 5  debt_consolidation   60 months     Current   4333.333333

# %% [markdown]
# #### Using Monthly income, create 'Installment_risk' - which is a rate calculated as such: installment_risk = installment/monthly_inc. The higher the number, the higher the risk of an applicant defaulting

# %%
useful_data['installment_risk'] = useful_data['installment']/useful_data['monthly_inc']

# %%
useful_data.head()
# Out:
#    loan_amnt  installment  annual_inc grade  open_acc  total_pymnt  \
# 0     5000.0       186.82     50000.0     D       5.0  2043.690000
# 1    15000.0       483.45    196000.0     B      19.0  5301.420000
# 3    25000.0       688.35     65000.0     D       7.0  7511.160000
# 4     3000.0        93.10     52000.0     A       7.0  3011.577285
# 5    17000.0       454.10     52000.0     D       9.0  4956.590000
#
#    total_rec_int home_ownership verification_status application_type  \
# 0         824.00           RENT            Verified       Individual
# 1        1179.92            OWN     Source Verified       Individual
# 3        4699.89       MORTGAGE     Source Verified       Individual
# 4          11.58           RENT     Source Verified       Individual
# 5        2976.36           RENT     Source Verified       Individual
#
#               purpose        term loan_status   monthly_inc  installment_risk
# 0               other   36 months     Current   4166.666667          0.044837
# 1  debt_consolidation   36 months     Current  16333.333333          0.029599
# 3  debt_consolidation   60 months     Current   5416.666667          0.127080
# 4      major_purchase   36 months  Fully Paid   4333.333333          0.021485
# 5  debt_consolidation   60 months     Current   4333.333333          0.104792

# %% [markdown]
# #### creating final working dataframe

# %%
final_df = useful_data

# %%
# values in loan status
final_df['loan_status'].unique()
# Out:
# array(['Current', 'Fully Paid', 'Late (31-120 days)', 'Late (16-30 days)',
#        'Charged Off', 'Default', 'In Grace Period'], dtype=object)

# %%
# bucket them into 2 categories, Normal and Default
# 'Current', 'Fully Paid' = Normal
# 'Late (31-120 days)', 'Late (16-30 days)', 'Charged Off', 'Default', 'In Grace Period' = Default

# %%
# Create conditions for new column
conditions = [
    (final_df['loan_status']=='Current') | (final_df['loan_status']=='Fully Paid'),
    (final_df['loan_status']=='Late (31-120 days)') | (final_df['loan_status']=='Late (16-30 days)') | (final_df['loan_status']=='Charged Off') | (final_df['loan_status']=='Default') | (final_df['loan_status']=='In Grace Period'),
]

# %%
# Create values for the conditions
values = ['Normal','Default']

# %%
final_df['loan_category'] = np.select(conditions, values)

# %%
final_df
# Out:
#         loan_amnt  installment  annual_inc grade  open_acc   total_pymnt  \
# 0          5000.0       186.82     50000.0     D       5.0   2043.690000
# 1         15000.0       483.45    196000.0     B      19.0   5301.420000
# 3         25000.0       688.35     65000.0     D       7.0   7511.160000
# 4          3000.0        93.10     52000.0     A       7.0   3011.577285
# 5         17000.0       454.10     52000.0     D       9.0   4956.590000
# ...           ...          ...         ...   ...       ...           ...
# 495237    12000.0       398.46     60000.0     B      16.0   3570.170000
# 495238     3000.0       112.09     72000.0     D      11.0   1117.500000
# 495239    14000.0       492.27     52874.0     C       9.0   5402.520000
# 495240     7500.0       245.19    126000.0     B      16.0   2688.010000
# 495241    35000.0      1065.88    110000.0     A      13.0  11712.880000
#
#         total_rec_int home_ownership verification_status application_type  \
# 0              824.00           RENT            Verified       Individual
# 1             1179.92            OWN     Source Verified       Individual
# 3             4699.89       MORTGAGE     Source Verified       Individual
# 4               11.58           RENT     Source Verified       Individual
# 5             2976.36           RENT     Source Verified       Individual
# ...               ...            ...                 ...              ...
# 495237         959.71       MORTGAGE        Not Verified       Individual
# 495238         457.68           RENT        Not Verified       Individual
# 495239        1808.79       MORTGAGE        Not Verified       Individual
# 495240         649.38           RENT        Not Verified       Individual
# 495241        1684.59           RENT     Source Verified       Individual
#
#                    purpose        term        loan_status   monthly_inc  \
# 0                    other   36 months            Current   4166.666667
# 1       debt_consolidation   36 months            Current  16333.333333
# 3       debt_consolidation   60 months            Current   5416.666667
# 4           major_purchase   36 months         Fully Paid   4333.333333
# 5       debt_consolidation   60 months            Current   4333.333333
# ...                    ...         ...                ...           ...
# 495237      major_purchase   36 months        Charged Off   5000.000000
# 495238               other   36 months  Late (16-30 days)   6000.000000
# 495239  debt_consolidation   36 months            Current   4406.166667
# 495240               other   36 months            Current  10500.000000
# 495241  debt_consolidation   36 months            Current   9166.666667
#
#         installment_risk loan_category
# 0               0.044837        Normal
# 1               0.029599        Normal
# 3               0.127080        Normal
# 4               0.021485        Normal
# 5               0.104792        Normal
# ...                  ...           ...
# 495237          0.079692       Default
# 495238          0.018682       Default
# 495239          0.111723        Normal
# 495240          0.023351        Normal
# 495241          0.116278        Normal
#
# [426257 rows x 16 columns]
